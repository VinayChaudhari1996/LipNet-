# %%
# !python -V
# Out:
# Python 3.7.12

# %%
# !git clone https://github.com/rizkiarm/LipNet.git
# Out:
# Cloning into 'LipNet'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 352 (delta 4), reused 0 (delta 0), pack-reused 343
# Receiving objects: 100% (352/352), 125.85 MiB | 21.85 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# Checking out files: 100% (134/134), done.

# %%
# %cd LipNet/
# %pip install -e .
# Out:
# /content/LipNet/LipNet
# Obtaining file:///content/LipNet/LipNet
# ...
#   Using cached https://files.pythonhosted.org/packages/f9/d5/f24f86b51298f171826a398efdd64b5214b687a28a2f05ff736b1505b1b2/numpy-1.12.1-cp27-cp27mu-manylinux1_x86_64.whl
# ...
# ERROR: librosa 0.6.3 has requirement scipy>=1.0.0, but you'll have scipy 0.19.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: torchvision 0.5.0 has requirement pillow>=4.1.1, but you'll have pillow 4.1.0 which is incompatible.
# ERROR: pyarrow 0.14.0 has requirement numpy>=1.14, but you'll have numpy 1.12.1 which is incompatible.
# ERROR: imgaug 0.2.9 has requirement numpy>=1.15.0, but you'll have numpy 1.12.1 which is incompatible.
# ERROR: featuretools 0.4.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ERROR: blis 0.2.4 has requirement numpy>=1.15.0, but you'll have numpy 1.12.1 which is incompatible.
# ...

# %%
# !pip -V
# Out:
# pip 19.3.1 from /usr/local/lib/python2.7/dist-packages/pip (python 2.7)

# %%
# !pip install tensorflow==1.15
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/3a/5f/47e578b3ae79e2624e205445ab77a1848acdaa2929a00eeef6b16eaaeb20/numpy-1.16.6-cp27-cp27mu-manylinux1_x86_64.whl
# ...
# ERROR: cvxpy 1.0.15 has requirement scipy>=1.1.0, but you'll have scipy 0.19.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: torchvision 0.5.0 has requirement pillow>=4.1.1, but you'll have pillow 4.1.0 which is incompatible.
# ERROR: scikit-image 0.14.3 has requirement pillow>=4.3.0, but you'll have pillow 4.1.0 which is incompatible.
# ERROR: mir-eval 0.5 has requirement scipy>=1.0.0, but you'll have scipy 0.19.0 which is incompatible.
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.4.0 which is incompatible.
# ERROR: pymc3 3.6 has requirement h5py>=2.7.0, but you'll have h5py 2.6.0 which is incompatible.
# ...

# %%
import tensorflow

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.0

# %%
# %ls
# Out:
# assets/  evaluation/  lipnet/           predict*   scripts/   tests/  training/
# common/  LICENSE      lipnet.egg-info/  README.md  setup.py*  train*

# %%
# %cd LipNet
# Out:
# [Errno 2] No such file or directory: 'LipNet'
# /content/LipNet/LipNet

# %%
ls
# Out:
# assets/  evaluation/  lipnet/           predict*   scripts/   tests/  training/
# common/  LICENSE      lipnet.egg-info/  README.md  setup.py*  train*

# %% [markdown]
# # Test : 1

# %%
# !bash predict evaluation/models/overlapped-weights368.h5 evaluation/samples/id2_vcd_swwp2s.mpg
# Out:
# Using TensorFlow backend.
#
# Loading data from disk...
# /usr/local/lib/python2.7/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python2.7/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Data loaded.
#
# WARNING: Logging before flag parsing goes to stderr.
# W1019 13:20:46.749655 139692927395712 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:349: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %% [markdown]
# # Test : 2

# %%
import os

def fun():
  print("Running...")
  os.system("bash predict evaluation/models/overlapped-weights368.h5 /content/LipNet/evaluation/samples/GRID/brbk7n.mpg")

# %% [markdown]
# # Inference

# %%
# !bash predict evaluation/models/overlapped-weights368.h5 /content/LipNet/evaluation/samples/GRID/lbbc2a.mpg
# Out:
# Using TensorFlow backend.
#
# Loading data from disk...
# /usr/local/lib/python2.7/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python2.7/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Data loaded.
#
# WARNING: Logging before flag parsing goes to stderr.
# W1019 13:23:32.728012 139697869772672 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:349: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
